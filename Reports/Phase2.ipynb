# %% [markdown]
# # Phase 1
#
# ## 1- Goal:
#
#  Our goal is to delve into the data, investigating and analyzing it to identify potential risk factors and gain insights into the demographics most susceptible to strokes. By leveraging this dataset, we intend to predict the likelihood of a patient experiencing a stroke based on parameters such as gender, age, existing medical conditions, and smoking status. Each entry in the dataset furnishes pertinent details about the patient, facilitating comprehensive analysis and predictive modeling.
# classification goal involve using data mining to build a predictive model that classifies individuals into two categories: those at high risk of experiencing a stroke and those at low risk.
#
#
#
# ## 2- Dataset:
#
# Our dataset source is Kaggle : <https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset>
#
#
# ## 3- Genral info about the dataset:
#
# Among the 5110 objects in our dataset sample, 12 attributes are used to describe them. (See Table 1).
#  the class label for our dataset is Stroke hat took two values 1 and 0 to indicate whether they are sufferd from it or not.
#
#  ##### Table 1: General Information about the attributes

# %% [markdown]
# | Attributes name   | Description                                                 | Data type | Rangee values
# |-------------------|-------------------------------------------------------------|-----------|-----------------
# | id                | Unique id of the patient                                    | Nominal   |
# | gender            | Gender of the patient                                       | Binary    |
# | age               | Age of the patient                                          | Numeric   | Range between 0.08- 82
# | hypertension      | 1 means the patient has hypertension,0 means they do not.   | Binary    | 0,1
# | heart_disease     | 1 means the patient has heart disease,0 means they do not.  | Binary    | 0,1
# | ever_married      | Has the patient ever been married?                          | Binary    | yes,no
# | work_type         | Work type of the patient                                    | Nominal   | “Private”, “Self-employed”, “children”, “Govt_job”, “Never_worked”
# | residence_type    | Residence type of the patient                               | Binary    | Urban,Rural
# | avg_glucose_level | Average glucose level in blood                              | Numeric   | between 55.1- 272
# | bmi               | Body Mass Index                                             | Numeric   | between 10.3- 97.6
# | Smoking state     | whether or not smokes                                       | Nominal   | “never smoked”, “Unknown”, “formerly smoked”, “smokes”
# | stroke            | 1 means the patient had a stroke, 0 means not               | Binary    | 0,1

# %% [markdown]
# ## Dataset:

# %%
####Dataset types:

import pandas as pd
df = pd.read_csv("StrokeDS.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 500 non-null    int64
#  1   gender             500 non-null    object
#  2   age                500 non-null    float64
#  3   hypertension       500 non-null    int64
#  4   heart_disease      500 non-null    int64
#  5   ever_married       500 non-null    object
#  6   work_type          500 non-null    object
#  7   Residence_type     500 non-null    object
#  8   avg_glucose_level  500 non-null    float64
#  9   bmi                455 non-null    float64
#  10  smoking_status     500 non-null    object
#  11  stroke             500 non-null    int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 37.2+ KB
# None

# %%
####Sample first 3 rows:

import pandas as pd
df = pd.read_csv("StrokeDS.csv")
print(df.head(3))
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1

# %% [markdown]
# # Phase 2

# %% [markdown]
# ### Dataset summary

# %%
import pandas as pd


data = pd.read_csv('StrokeDS.csv')


summary = data.describe()

print("Summary of the dataset:")
print(summary)
# Out:
# Summary of the dataset:
#                  id         age  hypertension  heart_disease  \
# count    500.000000  500.000000    500.000000     500.000000
# mean   36707.460000   55.127680      0.184000       0.120000
# std    21668.973917   21.980196      0.387872       0.325287
# min      129.000000    0.640000      0.000000       0.000000
# 25%    17303.750000   42.000000      0.000000       0.000000
# 50%    36404.500000   59.000000      0.000000       0.000000
# 75%    55712.500000   74.000000      0.000000       0.000000
# max    72918.000000   82.000000      1.000000       1.000000
#
#        avg_glucose_level         bmi      stroke
# count         500.000000  455.000000  500.000000
# mean          121.850820   30.132527    0.498000
# std            56.658618    7.749225    0.500497
# min            55.390000   13.800000    0.000000
# 25%            79.112500   25.050000    0.000000
# 50%            97.840000   28.900000    0.000000
# ...

# %% [markdown]
# The provided summary data offers insights into various variables within a dataset. It includes information on ID, gender, age, hypertension, heart disease, marital status, work type, residence type, average glucose level, body mass index (BMI), smoking status, and stroke occurrence.
#
# Each entry is assigned a unique numerical identifier, 'id', with a total count of 5110 entries. The range of these identifiers spans from 67 to 72940, suggesting that the dataset may have been filtered or sampled from a larger population.
#
# The 'gender' variable classifies entries into categories, with 'Female' being the predominant gender, occurring 2994 times. The 'age' variable, which is continuous, has an average value of approximately 43.22 years. The ages in the dataset start from as young as 0.08 years, indicating infants, and extend up to 82 years.
#
# The dataset includes two binary health-related variables: 'hypertension' and 'heart_disease'. Both represent the presence or absence of the respective conditions, with mean values suggesting that they are relatively uncommon within this dataset's population.
#
# Marital status is captured in the 'ever_married' variable, where the majority of entries, 3353, indicate a status of 'Yes'. Employment types are categorized under 'work_type', which consists of five distinct categories. Residential information is divided into 'Residence_type', with 'Urban' being more common, appearing 2596 times.
#
# The 'avg_glucose_level' variable, which is continuous, has an average value of 106.15, with a range that goes from a low of 55.12 to a high of 271.74. The 'bmi' variable reflects the Body Mass Index, an important health metric, which averages around 28.89 across the dataset. Notably, 'bmi' has missing values, as its count is less than the total number of entries.
#
# The 'smoking_status' variable sorts individuals into four categories, with 'never smoked' being the most frequently observed status, with 1892 instances. Lastly, the 'stroke' column serves as the likely target variable for analysis or prediction tasks. It is a binary or categorical variable, with a mean value suggesting that strokes have occurred in approximately 4.8% of the dataset entries.
#
# In summary, the dataset represents a diverse population in terms of gender, age, and various health-related factors. It provides insights into hypertension, heart disease, and stroke occurrences, as well as lifestyle factors such as marital status, work type, residence type, and smoking status. The dataset is valuable for further analysis of factors associated with stroke occurrence and potential risk factors within the population.

# %%
import pandas as pd
data = pd.read_csv('StrokeDS.csv')


##mean
mean_value = data['bmi'].mean()
print(f"Mean of '{'bmi'}': {mean_value}")
mean_value = data['age'].mean()
print(f"Mean of '{'age'}': {mean_value}")
mean_value = data['avg_glucose_level'].mean()
print(f"Mean of '{'avg_glucose_level'}': {mean_value}")

##Varince
variance_value = data['bmi'].var()
print(f"Variance of '{'bmi'}': {variance_value}")
variance_value = data['age'].var()
print(f"Variance of '{'age'}': {variance_value}")
variance_value = data['avg_glucose_level'].var()
print(f"Variance of '{'avg_glucose_level'}': {variance_value}")
# Out:
# Mean of 'bmi': 28.893236911794666
# Mean of 'age': 43.226614481409
# Mean of 'avg_glucose_level': 106.1476771037182
# Variance of 'bmi': 61.68636419426886
# Variance of 'age': 511.33179182433514
# Variance of 'avg_glucose_level': 2050.600819911376

# %% [markdown]
# The average age in the dataset is 43 years old. This means that if we were to take the sum of all the ages and divide it by the number of people, we would get 43. There is a variance of 273.5 years old. This tells us how spread out the ages are from the average. A higher variance indicates that the ages are more spread out, while a lower variance suggests that the ages are clustered closer to the average.
#
# The average body mass index (BMI) is 27.72. Body mass index (BMI) is a measure of a person's weight relative to their height. A BMI of 25 or less is considered normal weight, 26 to 29.9 is considered overweight, and 30 or more is considered obese. There is a variance of 13.55  which indicates that there is a moderate spread out around the average BMI.
#
# The average blood sugar level is 103.4. Blood sugar level is an important indicator of diabetes. A normal blood sugar level is between 70 and 99 mg/dL. There is a variance of 440.95 which is relatively high. This suggests that there is a large variation in blood sugar levels across the individuals.

# %% [markdown]
# ## Grpahs

# %%
##Grpahs

import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('StrokeDS.csv')


tab = data['work_type'].value_counts()


percentages = (tab / tab.sum()).round(3) * 100


txt = [f"{name}\n{percent:.1f}%" for name, percent in zip(tab.index, percentages)]

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(tab, labels=txt, startangle=90)
plt.title("work tyoe pie Chart")
plt.axis('equal')  
plt.show()

# %% [markdown]
# This pie chart displays the distribution of worker types across different employment sectors in our dataset. The data is nominal, indicating that individuals working in the private sector comprise the largest percentage (58.6%), followed by those in the self-employed sector (21.6%), and so on.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('StrokeDS.csv')

x = data['bmi']
y = data['age']

plt.scatter(x, y)
plt.xlabel("Bmi")
plt.ylabel("age")

plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# This Scatter plot BMI's appears to be fairly consistent across different ages, with most data points clustered in the middle range of BMI values. The spread of BMI does not seem to increase or decrease with age, as there are individuals with varying BMI values across the entire age spectrum.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


data = pd.read_csv('StrokeDS.csv')


plt.figure(figsize=(10, 6))
plt.hist(data['avg_glucose_level'], bins=30, density=True, alpha=0.6, color='b', edgecolor='black')


mu, std = norm.fit(data['avg_glucose_level'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)


plt.xlabel('Avg. Glucose Level')
plt.ylabel('mean')
plt.title('Histogram of Avg. Glucose Level with Normal Distribution Overlay')
plt.show()

# %% [markdown]
# The average glucose levels of the patients in the study exhibit a right-skewed distribution, An increase in frequency is observed when the glucose level reaches 200, prompting consideration of whether this elevation is a contributing factor for a stroke.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('StrokeDS.csv')

data = data[data['gender'] != 'Other']

plt.figure(figsize=(8, 6))
data.groupby(['gender', 'stroke']).size().unstack().plot(kind='bar', stacked=True, color=['#1f77b4', '#ff7f0e'])
plt.title('Incident of stroke between genders')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Stroke', labels=['0', '1'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# The bar chart illustrates the total number of strokes by gender in our dataset, aiming to determine if there is a correlation between gender and the frequency of stroke cases. The data suggests that men are slightly more likely than women to experience a stroke.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('StrokeDS.csv')


plt.figure(figsize=(8, 6))
data.groupby(['ever_married', 'stroke']).size().unstack().plot(kind='bar', stacked=True, color=['#1f77b4', '#ff7f0e'])
plt.title('Correlation between stroke occurrence and marriage status')
plt.xlabel('Ever Married')
plt.ylabel('Count')
plt.legend(title='Stroke', labels=['0', '1'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# The bar graph illustrates the correlation between having a stroke and marital status. It reveals that married individuals have a higher risk of experiencing a stroke compared to those who are not married.

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('StrokeDS.csv')

class_counts = df['stroke'].value_counts()

# Plot the distribution
plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar')
plt.xlabel('Class Label')
plt.ylabel('Frequency')
plt.title('Distribution of Class Label')
plt.show()

# %% [markdown]
# Each bar's height reflects the number of individuals in each category, and since the bars are of equal height, it indicates an equal number of observations for both classes. This means the dataset has an equal distribution of cases with and without stroke incidents,This balanced dataset is a result of controlled sampling

# %% [markdown]
# ### finding the missing values

# %%
###finding the missing values 
import pandas as pd

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 500 non-null    int64
#  1   gender             500 non-null    object
#  2   age                500 non-null    float64
#  3   hypertension       500 non-null    int64
#  4   heart_disease      500 non-null    int64
#  5   ever_married       500 non-null    object
#  6   work_type          500 non-null    object
#  7   Residence_type     500 non-null    object
#  8   avg_glucose_level  500 non-null    float64
#  9   bmi                455 non-null    float64
#  10  smoking_status     500 non-null    object
#  11  stroke             500 non-null    int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 37.2+ KB

# %%
nan_counts = df.isna().sum()

# Print the columns that have NaN values and their counts
print(nan_counts[nan_counts > 0])
# Out:
# bmi    45
# dtype: int64

# %% [markdown]
# ### Replacing null values with the mean

# %%
###Replacing null values with the mean
import pandas as pd

numeric_columns = ['bmi'] 
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].mean())
df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
print(data)
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 1    51676  Female  61.0             0              0          Yes
# 2    31112    Male  80.0             0              1          Yes
# 3    60182  Female  49.0             0              0          Yes
# 4     1665  Female  79.0             1              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 495  34299  Female  71.0             0              0          Yes
# 496  54375    Male   5.0             0              0           No
# 497  37832  Female  14.0             0              0           No
# 498  21058  Female  15.0             0              0           No
# 499   7696  Female  66.0             0              0           No
#
#          work_type Residence_type  avg_glucose_level        bmi  \
# 0          Private          Urban             228.69  36.600000
# ...

# %% [markdown]
# ## Data Preprocessing
#
# In our data, we performed several data preprocessing techniques such as data cleaning, data normalization, removing outliers, etc. We’ll go through each one in details below.

# %% [markdown]
# #### Check duplicated rows
#
# We check if there are any duplicated rows to decrease dataset volume. Hence enhancing data quality which leads to better model performance and speed.

# %%
import pandas as pd
duplicates = data.duplicated()


print("Number of duplicate rows:", duplicates.sum())


print(data[duplicates])
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# ## Removing nose
# Our data cleaning process included identifying and handling outliers, which can skew statistical models. Outliers are extreme values that differ from the bulk of the data. To ensure the accuracy of our analysis, we implemented an outlier detection technique. This method effectively pinpointed potential outliers, allowing us to address them appropriately.

# %%
import pandas as pd
from scipy import stats
import numpy as np

# Function
def find_outliers(df):
    outlier_dict = {}
    for column in df.select_dtypes(include=[np.number]):  # This ensures we're only checking numeric columns
        if df[column].isna().any():
            df[column].fillna(df[column].median(), inplace=True)  # Handling NaNs by median imputation
        z_scores = np.abs(stats.zscore(df[column]))
        threshold = 3
        outliers = np.where(z_scores > threshold)
        if outliers[0].size > 0:
            outlier_dict[column] = len(outliers[0])
    return outlier_dict

# Checking for outliers
outliers = find_outliers(data)
print("Columns with outliers and their count:")
for column, count in outliers.items():
    print(f"{column}: {count} outliers")
# Out:
# Columns with outliers and their count:
# bmi: 7 outliers

# %%
# Function to remove outliers based on IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
cleaned_data = remove_outliers(df, 'bmi')

# %% [markdown]
# ## Encoding categorical data:
#
#
# Encoding is an important step in data mining and machine learning tasks because it transforms raw data into a suitable format that can be effectively processed and analyzed by algorithms. The process of encoding involves converting categorical or textual data into numerical representations.

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from scipy import stats



le = LabelEncoder()


df['work_type'] = le.fit_transform(df['work_type'])
df['gender'] = le.fit_transform(df['gender'])
df['ever_married'] = le.fit_transform(df['ever_married'])
df['Residence_type'] = le.fit_transform(df['Residence_type'])
df['smoking_status'] = le.fit_transform(df['smoking_status'])


print(df)
# Out:
#         id  gender       age  hypertension  heart_disease  ever_married  \
# 0     9046       1  0.540678             0              1             1
# 1    51676       0  0.267432             0              0             1
# 2    31112       1  1.132712             0              1             1
# 3    60182       0 -0.279061             0              0             1
# 4     1665       0  1.087171             1              0             1
# ..     ...     ...       ...           ...            ...           ...
# 495  34299       0  0.722842             0              0             1
# 496  54375       1 -2.282868             0              0             0
# 497  37832       0 -1.872998             0              0             0
# 498  21058       0 -1.827457             0              0             0
# 499   7696       0  0.495137             0              0             0
#
#      work_type  Residence_type  avg_glucose_level           bmi  \
# ...

# %%
import pandas as pd



# Select only numeric columns for checking negative values
numeric_df = df.select_dtypes(include='number')

# Check for negative values in the numeric columns
negative_values = numeric_df[numeric_df < 0]

# Sum the negative values to see if there are any
print("Negative values in each column:\n", negative_values.sum())
# Out:
# Negative values in each column:
#  id                     0.000000
# gender                 0.000000
# age                 -227.853410
# hypertension           0.000000
# heart_disease          0.000000
# ever_married           0.000000
# work_type              0.000000
# Residence_type         0.000000
# avg_glucose_level   -209.033915
# bmi                 -170.140955
# smoking_status         0.000000
# stroke                 0.000000
# dtype: float64

# %%
for column in df.columns:
    mean_value = df[column].mean()
    df[column] = df[column].apply(lambda x: mean_value if x < 0 else x)

# %%
# Ensure no negative values remain
print("Negative values in each column after cleaning:\n", (df < 0).sum())
# Out:
# Negative values in each column after cleaning:
#  id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# ## Discretization
#
# After the process of normalizing and cleaning the data, we found that there is no requirement for feature discretization.

# %% [markdown]
# ## Normalize Data using Min-Max Scaling:
#
# Normalization was performed to ensure consistent data scale. The normalization technique applied is max-min normalization. This technique scales specific attribute values ​​to a specified range from 0 to 1. The following attributes were selected for normalization: age, average blood glucose level, and BMI (body mass index). can). We can use a standardized data set to provide a more consistent and comparable representation of  attributes, allowing accurate analysis and modeling to predict stroke  with specified results. determined.

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd




columns_to_normalize = ['avg_glucose_level', 'age', 'bmi']  

zscore_scaler = StandardScaler()
normalized_data_zscore = zscore_scaler.fit_transform(df[columns_to_normalize])


df[columns_to_normalize] = normalized_data_zscore

print("Z-score normalized data:")
print(df)
# Out:
# Z-score normalized data:
#         id  gender       age  hypertension  heart_disease  ever_married  \
# 0     9046       1 -0.629287             0              1             1
# 1    51676       0 -0.629287             0              0             1
# 2    31112       1  1.960931             0              1             1
# 3    60182       0 -0.629287             0              0             1
# 4     1665       0  1.732522             1              0             1
# ..     ...     ...       ...           ...            ...           ...
# 495  34299       0 -0.094756             0              0             1
# 496  54375       1 -0.629287             0              0             0
# 497  37832       0 -0.629287             0              0             0
# 498  21058       0 -0.629287             0              0             0
# 499   7696       0 -0.629287             0              0             0
#
# ...

# %% [markdown]
# ## Feature selection
#
# we will use a feature selection tool called recursive feature elimination (RFE) to reduce the number of input variables in a predictive model. This is a widely used algorithm to select the most relevant features for prediction of the prediction target variable

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split



X = df.drop('stroke', axis=1)  
y = df['stroke']


X = pd.get_dummies(X)


imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.3, random_state=7)


scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = LogisticRegression(max_iter=1000) 
rfe = RFE(model, n_features_to_select=2) 
X_train_selected = rfe.fit_transform(X_train_scaled, y_train)
X_test_selected = rfe.transform(X_test_scaled)

# Display the selected features
selected_features = [feature for feature, selected in zip(X.columns, rfe.support_) if selected]
print("Selected features:", selected_features)
# Out:
# Selected features: ['age', 'avg_glucose_level']

# %%
df.to_csv('Processed_StrokeDS.csv', index=False)
